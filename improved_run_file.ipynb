# %%
! pip install numpy pandas matplotlib seaborn scikit-learn
! pip install --upgrade pip
! pip install shapely
! pip install trimesh
! pip install triangle
! pip install pyvista
! pip install cv2-python
! pip install torch
! pip install torchnn
! pip install opencv-python
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement cv2-python (from versions: none)
# ERROR: No matching distribution found for cv2-python
# ...

# %%
! python3 -m venv .venv && source .venv/bin/activate
! python -m pip install --upgrade pip
! pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu  # Mac M works with MPS even on "cpu" wheel
! pip install albumentations opencv-python tqdm numpy scikit-image matplotlib
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.9.1-cp312-none-macosx_11_0_arm64.whl.metadata (29 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.24.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.9 kB)
# ...
#   Using cached https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached https://download.pytorch.org/whl/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached https://download.pytorch.org/whl/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...

# %%
# 1) Activate your Python env
! python3 -m venv .venv && source .venv/bin/activate
! pip install opencv-python numpy

# 2) Run the prep script on your folder of plans
! python prep_split_and_weaklabels_improved.py \
  --in_dir "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/raw_data/images" \
  --out_root "./improved/data" \
  --val_ratio 0.15 --test_ratio 0.10 --copy
# Out:
# ...
# Found 2640 images → train=1980 val=396 test=264
# [train] generating weak masks…
# [val] generating weak masks…
# [train] unique labels across masks: [1, 4]
# [val] unique labels across masks: [1, 4]
#
# Done. Data root ready at: ./improved/data
# Layout:
#   images/train, images/val, images/test
#   masks/train (weak), masks/val (weak)
# Classes present in these masks: 0=bg, 1=wall, 4=room
# Classes 2 (door) & 3 (window) are reserved for future annotations.

# %%
! python train_unet_improved.py
# Out:
# /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Sena_PROJECT/FINAL/train_unet_improved.py:40: UserWarning: Argument(s) 'mode, cval, cval_mask' are not valid for transform Affine
#   A.Affine(scale=(0.95, 1.05),
# Epoch 1/60: 100%|█████████████████████████| 1980/1980 [1:25:16<00:00,  2.58s/it]
# [E01] train_loss=0.3104  val_loss=0.2843  mIoU=0.8161
#    ↳ saved best to runs_unet_improved/best.pt (mIoU=0.8161)
# Epoch 2/60: 100%|███████████████████████████| 1980/1980 [19:17<00:00,  1.71it/s]
# [E02] train_loss=0.2684  val_loss=0.3519  mIoU=0.7154
# Epoch 3/60: 100%|███████████████████████████| 1980/1980 [20:37<00:00,  1.60it/s]
# [E03] train_loss=0.2503  val_loss=0.2583  mIoU=0.8370
#    ↳ saved best to runs_unet_improved/best.pt (mIoU=0.8370)
# Epoch 4/60: 100%|███████████████████████████| 1980/1980 [19:48<00:00,  1.67it/s]
# [E04] train_loss=0.2609  val_loss=0.4589  mIoU=0.5377
# Epoch 5/60: 100%|███████████████████████████| 1980/1980 [20:32<00:00,  1.61it/s]
# ...

# %%
! python infer_unet_improved.py
# Out:
# Found 264 images. Starting batch inference...
#
# [1/264] Processing: 82_10.jpg
# Wrote polygons JSON: pred_unet_improved/82_10_polygons.json
# [2/264] Processing: 36_5.jpg
# Wrote polygons JSON: pred_unet_improved/36_5_polygons.json
# [3/264] Processing: 85_19.jpg
# Wrote polygons JSON: pred_unet_improved/85_19_polygons.json
# [4/264] Processing: 92_29.jpg
# Wrote polygons JSON: pred_unet_improved/92_29_polygons.json
# [5/264] Processing: 82_8.jpg
# Wrote polygons JSON: pred_unet_improved/82_8_polygons.json
# [6/264] Processing: 92_15.jpg
# Wrote polygons JSON: pred_unet_improved/92_15_polygons.json
# [7/264] Processing: 47_12.jpg
# Wrote polygons JSON: pred_unet_improved/47_12_polygons.json
# [8/264] Processing: 34_17.jpg
# Wrote polygons JSON: pred_unet_improved/34_17_polygons.json
# [9/264] Processing: 71_12.jpg
# Wrote polygons JSON: pred_unet_improved/71_12_polygons.json
# [10/264] Processing: 0_25.jpg
# Wrote polygons JSON: pred_unet_improved/0_25_polygons.json
# ...

# %%
! cd "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models"

! python to3d_improved.py
# Out:
# Found 264 polygons files in /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Sena_PROJECT/FINAL/pred_unet_improved
#
# [1/264] 0_12_polygons.json → 0_12.glb
# 3D saved → out_3d_improved/0_12.glb
# [2/264] 0_16_polygons.json → 0_16.glb
# 3D saved → out_3d_improved/0_16.glb
# [3/264] 0_19_polygons.json → 0_19.glb
# 3D saved → out_3d_improved/0_19.glb
# [4/264] 0_1_polygons.json → 0_1.glb
# 3D saved → out_3d_improved/0_1.glb
# [5/264] 0_25_polygons.json → 0_25.glb
# 3D saved → out_3d_improved/0_25.glb
# [6/264] 10_13_polygons.json → 10_13.glb
# 3D saved → out_3d_improved/10_13.glb
# [7/264] 10_15_polygons.json → 10_15.glb
# 3D saved → out_3d_improved/10_15.glb
# [8/264] 10_28_polygons.json → 10_28.glb
# 3D saved → out_3d_improved/10_28.glb
# [9/264] 13_10_polygons.json → 13_10.glb
# 3D saved → out_3d_improved/13_10.glb
# [10/264] 13_22_polygons.json → 13_22.glb
# 3D saved → out_3d_improved/13_22.glb
# [11/264] 14_10_polygons.json → 14_10.glb
# 3D saved → out_3d_improved/14_10.glb
# ...

# %%
from IPython.display import HTML

HTML('''
<script type="module" src="https://unpkg.com/@google/model-viewer@3.4.0/dist/model-viewer.min.js"></script>
''')
# Out:
# <script type="module" src="https://unpkg.com/@google/model-viewer@3.4.0/dist/model-viewer.min.js"></script>

# %%
from IPython.display import HTML

glb_path = "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/5_16.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/5_16.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>

# %%
from IPython.display import HTML

glb_path = "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/3_4.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/3_4.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>

# %%
from IPython.display import HTML

glb_path = "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/14_7.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved/14_7.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>

# %%
! cd "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models"

! python to3d_improved_colour.py
# Out:
# Found 264 polygons files in /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/pred_unet_improved
#
# [1/264] 0_12_polygons.json → 0_12.glb
# [auto-scale] avg wall thickness: 115.00px, scale_factor: 0.400
# 3D saved → out_3d_improved_colour/0_12.glb
# [2/264] 0_16_polygons.json → 0_16.glb
# [auto-scale] avg wall thickness: 57.11px, scale_factor: 0.525
# 3D saved → out_3d_improved_colour/0_16.glb
# [3/264] 0_19_polygons.json → 0_19.glb
# [auto-scale] avg wall thickness: 139.20px, scale_factor: 0.400
# 3D saved → out_3d_improved_colour/0_19.glb
# [4/264] 0_1_polygons.json → 0_1.glb
# [auto-scale] avg wall thickness: 55.74px, scale_factor: 0.538
# 3D saved → out_3d_improved_colour/0_1.glb
# [5/264] 0_25_polygons.json → 0_25.glb
# [auto-scale] avg wall thickness: 48.52px, scale_factor: 0.618
# 3D saved → out_3d_improved_colour/0_25.glb
# [6/264] 10_13_polygons.json → 10_13.glb
# ...

# %%
from IPython.display import HTML

glb_path = "/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved_colour/9_7.glb"

HTML(f"""
<model-viewer src="{glb_path}"
    camera-controls
    auto-rotate
    environment-image="neutral"
    style="width:100%; height:600px; background:black;">
</model-viewer>
""")
# Out:
# <model-viewer src="/Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/out_3d_improved_colour/9_7.glb"
#     camera-controls
#     auto-rotate
#     environment-image="neutral"
#     style="width:100%; height:600px; background:black;">
# </model-viewer>

# %%
! pip install flask
# Out:
# ...
#   Using cached flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Using cached flask-3.1.2-py3-none-any.whl (103 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [flask]32m4/5 [flask]
# ...

# %%
! python app.py
# Out:
# Loading UNet model...
# Model loaded, device: mps
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# Loading UNet model...
# Model loaded, device: mps
#  * Debugger is active!
#  * Debugger PIN: 863-947-960
# 127.0.0.1 - - [24/Nov/2025 15:59:20] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Nov/2025 15:59:21] "GET / HTTP/1.1" 200 -
# Wrote polygons JSON: /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/web_pred/download (3)_polygons.json
# [warn] No wall polygons found in /Users/senakshikrishnamurthy/Desktop/DS/606 capstone/Capstone-From-2D-Civil-Floor-Drawings-to-3D-Models/web_pred/download (3)_polygons.json.
# ...
